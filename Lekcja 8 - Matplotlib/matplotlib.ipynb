# %% [markdown]
# # **1. IMPORTOWANIE**

# %%
# SPOSÓB 1  - importowanie całych modułów
import cs
import lol

lol.map_name()
lol.buy_ardent()

cs.map_name()
cs.buy_gun()
# Out:
# Summoner's Rift
# You have bought an Ardent Censer
# The Dust 2
# You have bought a gun

# %%
# SPOSÓB 2 - importowanie wybranych elementów modułu
from cs import map_name, buy_gun
from lol import buy_ardent

buy_gun()
buy_ardent()

map_name() # lol
# Out:
# You have bought a gun
# You have bought an Ardent Censer
# The Dust 2

# %%
# SPOSÓB 3 - importowanie wszytskich elementów
from cs import *
from lol import *

buy_gun()
buy_ardent()

map_name() # lol
# Out:
# You have bought a gun
# You have bought an Ardent Censer
# Summoner's Rift

# %%
# SPOSÓB 4 - importowanie z wykorzystaniem aliasów
from cs import map_name as cs_map
from cs import buy_gun as cs_gun
from lol import map_name as lol_map
from lol import buy_ardent as lol_ardent

cs_map()
lol_map()
# Out:
# The Dust 2
# Summoner's Rift

# %% [markdown]
# ## **2. MATPLOTPLIB**

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.10.0

# %%
# Ćwiczenie 1
import matplotlib.pyplot as plt
import numpy as np

# y = 2x - 1
# I
# xpoints = [-3, -2, -1, 0, 1, 2, 3]
# ypoints = [2*x - 1 for x in xpoints]

# II
# xpoints = np.array([-3, -2, -1, 0, 1, 2, 3])
# ypoints = 2 * xpoints - 1

# III
xpoints = np.arange(-3, 4, 1) # start, stop, step
ypoints = 2 * xpoints - 1

plt.plot(xpoints, ypoints, c='m', marker='o', linestyle='--', label="y=2x-1") #!!
plt.title("Wykres funkcji liniowej") #!!
plt.legend() #!!
plt.xlabel("Oś X") #!!
plt.ylabel("Oś Y") #!!
plt.grid()
plt.show()

# %%
# Zadanie
# W nowej sekcji kodu utwórz program rysujący wykres funkcji kwadratowej y = 2*x^2 - 3 na przedziale x = <-5;5>.

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.linspace(-5, 5, 100) # start, stop, step
ypoints = 2 * np.square(xpoints) - 3

plt.plot(xpoints, ypoints, c='c', linestyle=':', label="y = 2*x^2 - 3") #!!
plt.title("Wykres funkcji kwadratowej") #!!
plt.legend() #!!
plt.xlabel("Oś X") #!!
plt.ylabel("Oś Y") #!!
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x = np.random.rand(25)
y = np.random.rand(25)

plt.scatter(x, y, color='blue', marker='o', label="losowe punkty")
plt.title("Losowe punkty")
plt.legend()
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
import matplotlib.pyplot as plt

przedmioty = ["matma", "wf", "j.polski", "geografia", "j.angielski", "infa"]

procenty = [20, 15, 25, 10 , 10, 20]

plt.pie(procenty, labels=przedmioty, autopct='%1.1f%%',
colors=["red", "blue", "green", "orange", "purple", "magenta"])
plt.title("Przedmioty")
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
Z = np.sin(X) * np.cos(Y)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap="viridis")
plt.show()
# plt.savefig("wykres3D.png")

# %% [markdown]
# ZADANIA SAMODZIELNE:
# 1. Wygeneruj wykres funkcji na przedziale od -30 do 30 dla funkcj
#
# ```
# y = 5x + 131 dla x < -10
# y = x^2 - 19 dla x >= -10 && x < 10
# y = (x-9)^2 + 81 dla x >= 10
# ```
#
#
# 2. Wygeneruj na jednym wykresie wykres funkcji `y = cos(x)` i `y = sin(x)`
# 3. Samochód startuje z przyśpieszeniem 2 m/s. Narysuj wykres przebytej drogi i prędkości w czasie 15 sekund ruchu tego pojazdu. Wzór na prędkośc v(t) to at, a na drogę `s(t) = 1/2at^2`
#
# 4. Wygeneruj wykres kołowy zawierający skład powietrza. Skład procentowy gazów we wdychanym powietrzu wygląda tak: 78% azotu, 21% tlenu, 0,04% dwutlenku węgla oraz 1% pozostałych gazów.
